# %% [markdown]
# # Basic Charts
#
# * [Basic Correlation matrix ](#Basic_Correlation_matrix)
# * [Basic Bubble plot](#Basic_Bubble_plot)
# * [Basic area chart ](#basic_area_chart)
# * [Basic Venn diagram with 2 groups](#Basic_Venn_diagram_with_2_groups)
# * [Basic Venn diagram with 3 groups](#Basic_Venn_diagram_with_3_groups)
# * [Basic donut plot](#basic_donut_plot)
# * [Basic Treemap with python](#Basic_Treemap_with_python)
# * [Basic Matplotlib scatterplot](#Basic_Matplotlib_scatterplot)
# * [Basic seaborn scatterplot](#Basic_seaborn_scatterplot)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Basic Correlation matrix
# <a id = 'Basic_Correlation_matrix'></a>

# %%
# dataset
df = sns.load_dataset('iris')

# Basic correlogram
sns.pairplot(df)

# %% [markdown]
# ### Basic Bubble plot
# <a id = 'Basic_Bubble_plot'></a>

# %%
# create data
x = np.random.rand(40)
y = np.random.rand(40)
z = np.random.rand(40)
 
# use the scatter function
plt.scatter(x, y, s=z*1000, alpha=0.5)

# %% [markdown]
# ### basic area chart
# <a id = 'basic_area_chart'></a>

# %%
# Create data
x=range(1,6)
y=[1,4,6,8,4]
 
# Area plot
plt.fill_between(x, y)
 
# Note that we could also use the stackplot function:
#plt.stackplot(x,y)
# but fill_between is more convenient for future customization.

# %% [markdown]
# ### Basic Venn diagram with 2 groups
# <a id = 'Basic_Venn_diagram_with_2_groups'></a>

# %%
from matplotlib_venn import venn2

# First way to call the 2 group Venn diagram:
venn2(subsets = (10, 5, 2), set_labels = ('Group A', 'Group B'))

# %%
 # Second way
venn2([set(['A', 'B', 'C', 'D']), set(['D', 'E', 'F'])])

# %% [markdown]
# ### Basic Venn diagram with 3 groups
# <a id = 'Basic_Venn_diagram_with_3_groups'></a>

# %% [markdown]
# ### Basic lollipop plot
# <a id = 'Basic_lollipop_plot'></a>

# %%
# create data
x=range(1,41)
values=np.random.uniform(size=40)
 
# stem function: first way
plt.stem(x, values)
plt.ylim(0, 1.2)
# Out:
# <ipython-input-7-7307e0fc4e6e>:6: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(x, values)
# (0, 1.2)

# %%
# stem function: If no X provided, a sequence of numbers is created by python:
plt.stem(values)
# Out:
# <ipython-input-8-b9e61584c74b>:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(values)
# <StemContainer object of 3 artists>

# %%
# stem function: second way
(markerline, stemlines, baseline) = plt.stem(x, values)
plt.setp(baseline, visible=False)
# Out:
# <ipython-input-9-89c3c9226335>:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   (markerline, stemlines, baseline) = plt.stem(x, values)
# [None]

# %%
# Create a dataframe
import pandas as pd
df = pd.DataFrame({'group':list(map(chr, range(65, 85))), 'values':np.random.uniform(size=20) })
 
# Reorder it following the values:
ordered_df = df.sort_values(by='values')
my_range=range(1,len(df.index)+1)
 
# Make the plot
plt.stem(ordered_df['values'])
plt.xticks( my_range, ordered_df['group']);
# Out:
# <ipython-input-10-0b2fdb2bbf86>:10: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(ordered_df['values'])

# %%
# Vertical version.
plt.hlines(y=my_range, xmin=0, xmax=ordered_df['values'], color='skyblue')
plt.plot(ordered_df['values'], my_range, "D")
plt.yticks(my_range, ordered_df['group'])
plt.show()

# %%
plt.hlines(y=my_range, xmin=0, xmax=ordered_df['values'], color='skyblue')
plt.plot(ordered_df['values'], my_range, "D")
plt.yticks(my_range, ordered_df['group']);

# %% [markdown]
# ### Basic donut plot
# <a id = 'basic_donut_plot'></a>

# %%
# create data
size_of_groups=[12,11,3,30]
 
# Create a pieplot
plt.pie(size_of_groups)
#plt.show()
 
# add a circle at the center
my_circle=plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)

# %% [markdown]
# ### Basic Treemap with python
# <a id = 'Basic_Treemap_with_python'>

# %%
import squarify    # pip install squarify (algorithm for treemap)
 
# If you have 2 lists
squarify.plot(sizes=[13,22,35,5], label=["group A", "group B", "group C", "group D"], alpha=.7 )
plt.axis('off')
# Out:
# (0.0, 100.0, 0.0, 100.0)

# %%
df = pd.DataFrame({'nb_people':[8,3,4,2], 'group':["group A", "group B", "group C", "group D"] })
squarify.plot(sizes=df['nb_people'], label=df['group'], alpha=.8 )
plt.axis('off')
# Out:
# (0.0, 100.0, 0.0, 100.0)

# %%
# Change color
squarify.plot(sizes=[13,22,35,5], label=["group A", "group B", "group C", "group D"], color=["red","green","blue", "grey"], alpha=.4 )
plt.axis('off')
# Out:
# (0.0, 100.0, 0.0, 100.0)

# %%
import matplotlib
my_values=[i**3 for i in range(1,100)]
 
# create a color palette, mapped to these values
cmap = matplotlib.cm.Blues
mini=min(my_values)
maxi=max(my_values)
norm = matplotlib.colors.Normalize(vmin=mini, vmax=maxi)
colors = [cmap(norm(value)) for value in my_values]
 
# Change color
squarify.plot(sizes=my_values, alpha=.8, color=colors )
plt.axis('off')
# Out:
# (0.0, 100.0, 0.0, 100.0)

# %% [markdown]
# ### Basic Matplotlib scatterplot
# <a id = 'Basic_Matplotlib_scatterplot'>

# %%
# Create a dataset:
df=pd.DataFrame({'x': range(1,101), 'y': np.random.randn(100)*15+range(1,101) })
 
# plot
plt.plot( 'x', 'y', data=df, linestyle='none', marker='o')
# Out:
# <ipython-input-22-caa8fad4099e>:5: RuntimeWarning: Second argument 'y' is ambiguous: could be a color spec but is in data; using as data.  Either rename the entry in data or use three arguments to plot.
#   plt.plot( 'x', 'y', data=df, linestyle='none', marker='o')

# %% [markdown]
# ### Basic seaborn scatterplot
# <a id = 'Basic_seaborn_scatterplot'>

# %%
df = sns.load_dataset('iris')

# use the function regplot to make a scatterplot
sns.regplot(x=df["sepal_length"], y=df["sepal_width"])

# %%
# Without regression fit:
sns.regplot(x=df["sepal_length"], y=df["sepal_width"], fit_reg=False)
